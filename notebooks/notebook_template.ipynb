# %% [markdown]
# # Notebook Title
#
# Author:
#
# Date:
#
# Purpose:

# %% [markdown]
# ## Imports

# %%
from pathlib import Path

import pandas as pd

# %% [markdown]
# ## Load Data

# %%
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATA_PATH = PROJECT_ROOT / 'data' / '01_raw' / 'us_home_price_analysis_2004_2024.csv'
df = pd.read_csv(DATA_PATH)
df.head()

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Conclusions
